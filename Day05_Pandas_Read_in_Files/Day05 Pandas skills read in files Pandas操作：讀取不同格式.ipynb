# %% [markdown]
# # Day05 Pandas skills: read in files Pandas操作：讀取不同格式
#
# 先來介紹如何讀入(.csv)檔、以及Pandas一些基本常用指令解說：
# The first part will be about how to read in (.csv) files and some frequently used functions in Pandas.
#
# 演示程式碼讀入的是從[網站](https://dataportals.org/portal/berlin-open-data)下載的檔案。
# The data in my code was downloaded from [this site](https://dataportals.org/portal/berlin-open-data).

# %% [markdown]
# ## Read in CSV Files 讀入CSV檔

# %%
import pandas as pd # 載入套件並縮寫
df = pd.read_csv('example.csv') # 讀入後指定變數名稱df read in the file and name it df

# %% [markdown]
# 檔案讀進來後，使用一些基本指令來看一下資料，對資料有個概念。
#
# After reading in the file, we can use some functions to have a look of what the data is like.

# %%
# .head()功能預設讀出資料中前五筆，裡面可以裝整數，看要讀取前幾筆
# .head() will select the top n rows of the data, leave blank to get 5
df.head()
# Out:
#                        name                            title  \
# 0                 a2gov_org              Ann Arbor, Michigan
# 1  acikveri-sahinbey-bel-tr  Açık Veri Portali - Test Yayını
# 2          africa_open_data                 Africa Open Data
# 3   ajuntament-de-tarragona              Open Data Tarragona
# 4     ajuntament-de-terassa                Open Data Terassa
#
#                                                  url                   author  \
# 0  http://www.a2gov.org/services/data/Pages/defau...        City of Ann Arbor
# 1            http://acikveri.sahinbey.bel.tr/dataset                 pinardag
# 2                         http://africaopendata.org/         Africa Open Data
# 3                     http://opendata.tarragona.cat/  Ajuntament de Tarragona
# 4                      http://opendata.terrassa.cat/    Ajuntament de Terassa
#
#                  publisher      issued publisher_classification  \
# 0        City of Ann Arbor         NaN                      NaN
# 1     SahinBey Belediyesi   31/01/2015               Government
# 2         Africa Open Data         NaN                      NaN
# 3  Ajuntament de Tarragona         NaN               Government
# 4    Ajuntament de Terassa         NaN               Government
#
#                                          description               tags  \
# 0        City of Ann Arbor's Open Data Catalog (USA)  ctic unitedstates
# 1      The first official open data portal of Turkey    turkey national
# 2  Africa's largest central repository for Govern...        ckan africa
# 3                                Open Data Tarragona         city spain
# 4                                  Open Data Terassa         city spain
#
#   license_id  ...                place                location country  \
# 0        NaN  ...  Ann Arbor, Michigan  42.2681569,-83.7312291      US
# 1    Unknown  ...     Gaziantep,Turkey    37.0587715,37.380137      TR
# 2        NaN  ...               Africa    2.0000003,15.9999997      AF
# 3        NaN  ...            Tarragona         41.1157, 1.2496      ES
# 4        NaN  ...              Terrasa         41.5611, 2.0081      ES
#
#    language  status           metadatacreated    generator  \
# 0        en  active  2011-06-27T18:12:57.439Z          NaN
# 1        tr  active                       NaN          NaN
# 2        en  active  2013-03-15T07:17:26.251Z  CKAN: 2.1.3
# 3  ca es en  active                       NaN          NaN
# 4     es en  active                       NaN          NaN
#
#                      api_endpoint api_type full_metadata_download
# 0                    Not apparent      NaN                    NaN
# 1                             NaN      NaN                    NaN
# 2  http://africaopendata.org/api/      NaN                    NaN
# 3                             NaN      NaN                    NaN
# 4                             NaN      NaN                    NaN
#
# [5 rows x 21 columns]

# %%
# .tail()功能則是預設讀出資料中最後五筆，裡面可以裝整數，看要讀取最後幾筆
# .tail() on the other hand will select the bottom n rows of the data, leave blank to get 5
df.tail()
# Out:
#                                                   name  \
# 586  dados-abertos-tribunal-de-contas-do-estado-de-...
# 587         dados-abertos-prefeitura-de-belo-horizonte
# 588                                state_of_washington
# 589                                state_of_washington
# 590                                state_of_washington
#
#                                                  title  \
# 586  Dados Abertos – Tribunal de Contas do Estado d...
# 587  Portal de Dados Abertos – Prefeitura de Belo H...
# 588                                         Washington
# 589                                         Washington
# 590                                         Washington
#
#                                                    url  \
# 586  https://www.tce.pe.gov.br/internet/index.php/d...
# 587                          https://dados.pbh.gov.br/
# 588                                http://data.wa.gov/
# 589                                  http://geo.wa.gov
# 590                               http://fiscal.wa.gov
#
#                                                 author  \
# 586  Tribunal de Contas do Estado de Pernambuco (Co...
# 587  Município de Belo Horizonte (City of Belo Hori...
# 588                                State of Washington
# 589                                State of Washington
# 590                                State of Washington
#
#                                              publisher issued  \
# 586  Tribunal de Contas do Estado de Pernambuco (Co...    NaN
# 587  Município de Belo Horizonte (City of Belo Hori...    NaN
# 588                                State of Washington    NaN
# 589                                State of Washington    NaN
# 590                                State of Washington    NaN
#
#     publisher_classification  \
# 586               Government
# 587               Government
# 588               Government
# 589               Government
# 590               Government
#
#                                            description  \
# 586                                                NaN
# 587  Open data portal of the city of Belo Horizonte...
# 588        Public Open Data of the State of Washington
# 589  Geospatial open data from the State of Washington
# 590           Fiscal open data for state of Washington
#
#                             tags license_id  ...                       place  \
# 586       local-government,br-PE        NaN  ...                  PE, Brazil
# 587  local-government,br-MG,CKAN        NaN  ...  Belo Horizonte, MG, Brazil
# 588            ctic unitedstates        NaN  ...   Washington, United States
# 589                 unitedstates        NaN  ...   Washington, United States
# 590         finance unitedstates        NaN  ...   Washington, United States
#
#                    location country language  status  \
# 586         -8.451, -37.683      BR       pt  active
# 587      -19.9233, -43.9453      BR       pt  active
# 588  47.034922, -122.895756      US       en  active
# 589  47.034922, -122.895756      US       en  active
# 590  47.034922, -122.895756      US       en  active
#
#               metadatacreated generator                    api_endpoint  \
# 586      2019-06-03T15:40:44Z       NaN                             NaN
# 587      2019-06-03T15:40:44Z      CKAN  https://dados.pbh.gov.br/api/3
# 588  2011-06-27T18:16:05.479Z       NaN                             NaN
# 589                       NaN       NaN                             NaN
# 590                       NaN       NaN                             NaN
#
#                          api_type full_metadata_download
# 586                           NaN                    NaN
# 587                      CKAN API                    NaN
# 588  Socrata Open Data API (SODA)                    NaN
# 589           Esri ArcGIS Online                     NaN
# 590                           NaN                    NaN
#
# [5 rows x 21 columns]

# %% [markdown]
# ## .iloc[] 用法

# %%
# .iloc[a:b] 叫出指定列，清單中頭值包含，尾值不包含 
# .iloc[a:b] select rows by position. a included, b not included.
df.iloc[2:4]
# Out:
#                       name                title  \
# 2         africa_open_data     Africa Open Data
# 3  ajuntament-de-tarragona  Open Data Tarragona
#
#                               url                   author  \
# 2      http://africaopendata.org/         Africa Open Data
# 3  http://opendata.tarragona.cat/  Ajuntament de Tarragona
#
#                  publisher issued publisher_classification  \
# 2         Africa Open Data    NaN                      NaN
# 3  Ajuntament de Tarragona    NaN               Government
#
#                                          description         tags license_id  \
# 2  Africa's largest central repository for Govern...  ckan africa        NaN
# 3                                Open Data Tarragona   city spain        NaN
#
#    ...      place              location country  language  status  \
# 2  ...     Africa  2.0000003,15.9999997      AF        en  active
# 3  ...  Tarragona       41.1157, 1.2496      ES  ca es en  active
#
#             metadatacreated    generator                    api_endpoint  \
# 2  2013-03-15T07:17:26.251Z  CKAN: 2.1.3  http://africaopendata.org/api/
# 3                       NaN          NaN                             NaN
#
#   api_type full_metadata_download
# 2      NaN                    NaN
# 3      NaN                    NaN
#
# [2 rows x 21 columns]

# %%
# .iloc[a:b, c:d] 叫出[指定欄, 指定列]
# .iloc[a:b, c:d] select [rows, columns]
df.iloc[:, :5] # 叫出所有列，叫出前五欄 select all rows, the top five columns
# Out:
#                                                   name  \
# 0                                            a2gov_org
# 1                             acikveri-sahinbey-bel-tr
# 2                                     africa_open_data
# 3                              ajuntament-de-tarragona
# 4                                ajuntament-de-terassa
# ..                                                 ...
# 586  dados-abertos-tribunal-de-contas-do-estado-de-...
# 587         dados-abertos-prefeitura-de-belo-horizonte
# 588                                state_of_washington
# 589                                state_of_washington
# 590                                state_of_washington
#
#                                                  title  \
# 0                                  Ann Arbor, Michigan
# 1                      Açık Veri Portali - Test Yayını
# 2                                     Africa Open Data
# 3                                  Open Data Tarragona
# 4                                    Open Data Terassa
# ..                                                 ...
# 586  Dados Abertos – Tribunal de Contas do Estado d...
# 587  Portal de Dados Abertos – Prefeitura de Belo H...
# 588                                         Washington
# 589                                         Washington
# 590                                         Washington
#
#                                                    url  \
# 0    http://www.a2gov.org/services/data/Pages/defau...
# 1              http://acikveri.sahinbey.bel.tr/dataset
# 2                           http://africaopendata.org/
# 3                       http://opendata.tarragona.cat/
# 4                        http://opendata.terrassa.cat/
# ..                                                 ...
# 586  https://www.tce.pe.gov.br/internet/index.php/d...
# 587                          https://dados.pbh.gov.br/
# 588                                http://data.wa.gov/
# 589                                  http://geo.wa.gov
# 590                               http://fiscal.wa.gov
#
#                                                 author  \
# 0                                    City of Ann Arbor
# 1                                             pinardag
# 2                                     Africa Open Data
# 3                              Ajuntament de Tarragona
# 4                                Ajuntament de Terassa
# ..                                                 ...
# 586  Tribunal de Contas do Estado de Pernambuco (Co...
# 587  Município de Belo Horizonte (City of Belo Hori...
# 588                                State of Washington
# 589                                State of Washington
# 590                                State of Washington
#
#                                              publisher
# 0                                    City of Ann Arbor
# 1                                 SahinBey Belediyesi
# 2                                     Africa Open Data
# 3                              Ajuntament de Tarragona
# 4                                Ajuntament de Terassa
# ..                                                 ...
# 586  Tribunal de Contas do Estado de Pernambuco (Co...
# 587  Município de Belo Horizonte (City of Belo Hori...
# 588                                State of Washington
# 589                                State of Washington
# 590                                State of Washington
#
# [591 rows x 5 columns]

# %%
# .iloc[[], []] 叫出[指定欄, 指定列] 
# .iloc[[], []] select [[rows], [columns]]
df.iloc[[0], [0, 1, 2]]
# Out:
#         name                title  \
# 0  a2gov_org  Ann Arbor, Michigan
#
#                                                  url
# 0  http://www.a2gov.org/services/data/Pages/defau...

# %%
# .index叫出每列名稱
# .index will select the head of rows
df.index
# Out:
# RangeIndex(start=0, stop=591, step=1)

# %%
# .columns叫出每欄名稱
# .columns will select the head of columns
df.columns
# Out:
# Index(['name', 'title', 'url', 'author', 'publisher', 'issued',
#        'publisher_classification', 'description', 'tags', 'license_id',
#        'license_url', 'place', 'location', 'country', 'language', 'status',
#        'metadatacreated', 'generator', 'api_endpoint', 'api_type',
#        'full_metadata_download'],
#       dtype='object')

# %%
# .shape看資料框架有幾欄幾列
# .shape will call the dimension of the DataFrame
df.shape
# Out:
# (591, 21)

# %%
# .info查看資料框架的一些資訊
# .info will call the some information of the DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 591 entries, 0 to 590
# Data columns (total 21 columns):
# name                        591 non-null object
# title                       591 non-null object
# url                         591 non-null object
# author                      526 non-null object
# publisher                   531 non-null object
# issued                      89 non-null object
# publisher_classification    209 non-null object
# description                 542 non-null object
# tags                        515 non-null object
# license_id                  282 non-null object
# license_url                 53 non-null object
# place                       589 non-null object
# location                    568 non-null object
# country                     576 non-null object
# language                    582 non-null object
# status                      591 non-null object
# metadatacreated             448 non-null object
# generator                   88 non-null object
# api_endpoint                51 non-null object
# api_type                    80 non-null object
# full_metadata_download      15 non-null object
# dtypes: object(21)
# memory usage: 97.1+ KB

# %% [markdown]
# ## 以下簡短介紹幾種其他格式檔案讀取方式：Read in other formats:

# %% [markdown]
# ## Text 文本 (.txt)

# %%
with open('example.txt', 'r') as ex: # ’r’表示讀入 'r' means read in mode
    data = ex.readlines() # 逐行讀取並存成data read each lines and save as data
print(data)
# Out:
# ['這示範例文檔。This is the example file.\n', '這示範例文檔。This is the example file.\n', '這示範例文檔。This is the example file.']

# %% [markdown]
# ## 圖像檔 (.png/ .jpg ...) 圖像格式可以使用PIL、Skimage或CV2。
# ## Formats (.png/ .jpg ...) could be read in by packages like PIL, Skimage, and CV2.
#
# ### 用CV2讀取 Using CV2

# %%
# CV2的速度較快，但色彩模式會以BGR讀入 CV2 reads faster but in BGR mode
import cv2
image = cv2.imread('example.jpg') 
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) 
# 轉成RGB再存回變數 remember to convert to RGB mode and save back to variable

# %% [markdown]
# ### 用Skimage讀取 Using Skimage

# %%
import skimage.io as skio 
image = skio.imread('example.jpg')

# %% [markdown]
# ## 其他一些格式讀入方式。Read in some other formats.
#
# ### 矩陣檔(.mat) MATLAB使用的二進制數據容器格式文件。(.mat) is a binary data container.
# import scipy.io as sio # 載入Scipy
#
# data = sio.loadmat('example.mat')
#
# ### Python (.npy) 可以儲存經過處理後的資料。(.npy) is used to store processed data.
# import numpy as np
#
# arr = np.load('example.npy')
#
# ### Pickle (.pkl) 可以儲存經過處理後的資料。(.pkl) is used to store processed data.
# import pickle
#
# with open('example.pkl', 'rb') as ex:
#
#     arr = pickle.load(ex)
#
# ### Json (.json)
# import json # 先載入套件
#
# with open('example.json','r') as ex:
#
#     data = json.load(ex)
#
# 文中若有錯誤還望不吝指正，感激不盡。
# Please let me know if there’s any mistake in this article. Thanks for reading.
#
# Reference 參考資料：
#
# [1] 第二屆機器學習百日馬拉松內容
#
# [2] DataFrame, https://pandas.pydata.org/pandas-docs/stable/reference/frame.html#constructor
#
# [3] Berlin Open Data, https://dataportals.org/portal/berlin-open-data
